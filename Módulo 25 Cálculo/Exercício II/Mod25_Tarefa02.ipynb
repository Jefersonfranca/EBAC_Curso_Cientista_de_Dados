# %% [markdown]
# # Cálculo - Tarefa 02
#
# 1- Calcule de forma numérica a integral da função $x^3$ avaliada entre os pontos $1$ e $2$. Identifique o número de retângulos que você usou.
# 2- Calcule essa área de forma analítica.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from matplotlib.animation import FuncAnimation, PillowWriter 
from IPython.display import HTML
import warnings

# função
f = lambda x: x**3

def calcula_area(a, b, func, frame_num):
    # Intervalo de integração
    a = 1  # limite inferior
    b = 2  # limite superior

    num_bins=frame_num+1 # Quantidade de retângulos
    delta = (b-a)/num_bins # largura do retângulo
    x_cols = np.linspace(a, b-delta, num_bins) # Divisão do eixo X
    y_cols = f(x_cols) # alturas dos retângulos
    return sum(delta*y_cols)
    

def animate(n, a=1, b=2, func=f, verdadeiro_valor = 2):
    
    plt.cla()  # Limpa o gráfico anterior para montar o próxim frame
    ax = plt.axes(xlim=(a, b), ylim = (1, 8))  # Monta o sistema de eixos
    
    # Plota a função

    x = np.linspace(0, 10, 50)
    f = lambda x: x**3 
    y = f(x)
    ax.plot(x, y, '-');
    
    # Define as quebras e as alturas das colunas
    num_bins=n+1
    delta = (b-a)/num_bins
    x_cols = np.linspace(a, b-delta, num_bins)
    y_cols = f(x_cols)

    # plota barras
    bar = ax.bar(x_cols, y_cols, alpha=.5, width = delta, edgecolor='blue')   

    # Área dos retângulos
    soma_riemann = calcula_area(a, b, func, n)
    
    # Erro
    erro = verdadeiro_valor - soma_riemann
    ax.set_title(f'Área dos Retângulos = {soma_riemann:.2f} erro = {erro:.4f}')
    print(f"Área calculada numericamente: {soma_riemann}")
    print(f"Quantidade de retangulos: {n}")

    return bar
animate(50);
# Out:
# Área calculada numericamente: 3.6816608996539792
# Quantidade de retangulos: 50
